# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

options = Options()
options.page_load_strategy = 'eager'

# %%
driver = webdriver.Chrome()

url = 'https://phongtro123.com/tinh-thanh/da-nang'

def get_href(driver, url):
    driver.get(url)
    href_els = driver.find_elements(By.CLASS_NAME, 'line-clamp-2')

    url_list = []

    for el in href_els:
        href = el.get_attribute('href')
        if href is not None:
            url_list.append(href)
    
    return url_list
# Out:
# ['https://phongtro123.com/cho-thue-phong-tro-full-noi-that-486-pr712191.html',
#  'https://phongtro123.com/cho-thue-phong-tro-224-ho-nghinh-an-hai-da-nang-pr706394.html',
#  'https://phongtro123.com/chinh-chu-cho-thue-phong-tro-gia-sinh-vien-pr711141.html',
#  'https://phongtro123.com/gan-cho-cach-lang-dai-hoc-2km-kiet-rong-10m-3-huong-kiet-pr711006.html',
#  'https://phongtro123.com/trong-phong-vo-van-dong-quan-ngu-hanh-son-dt-40m2-co-ban-cong-pr710514.html',
#  'https://phongtro123.com/cho-thue-phong-tro-tai-ho-xuan-huong-ngu-hanh-son-da-nang-gia-2-9tr-pr711263.html',
#  'https://phongtro123.com/studio-full-noi-that-trung-tam-hai-chau-gan-cau-rong-pr711024.html',
#  'https://phongtro123.com/can-ho-mini-cao-cap-full-noi-that-moi-xay-ngay-trung-tam-tp-pr677825.html',
#  'https://phongtro123.com/cho-thue-phong-tro-rong-gac-lung-thoang-co-dieu-hoa-an-ninh-tot-wifi-mien-phi-pr709730.html',
#  'https://phongtro123.com/phong-tro-cho-khach-du-lich-khi-den-da-nang-pr709174.html',
#  'https://phongtro123.com/cho-nu-thue-phong-tro-hai-chau-trung-tam-tpdn-pr709049.html',
#  'https://phongtro123.com/cho-thue-phong-tro-tai-thanh-vinh-5-pr708927.html',
#  'https://phongtro123.com/cho-thue-phong-full-noi-that-trung-tam-duong-hoang-dieu-quan-hai-chau-da-nang-pr708797.html',
#  'https://phongtro123.com/thue-tro-800k-84-nguyen-chanh-lien-chieu-da-nang-pr650264.html',
#  'https://phongtro123.com/phong-20-m2-duong-hai-son-phuong-hai-chau-da-nang-pr708311.html',
#  'https://phongtro123.com/phong-tro-cho-thue-sat-lang-dai-hoc-da-nang-pr708105.html',
#  'https://phongtro123.com/cho-thue-can-ho-gia-re-ngay-canh-benh-vien-nhi-da-nang-bv-600-giuong-2-pr671989.html',
#  'https://phongtro123.com/cho-thue-phong-tro-382-37-19-nui-thanh-hoa-cuong-nam-hai-chau-pr707856.html',
#  'https://phongtro123.com/tinh-thanh/da-nang/nha-tro-cao-cap-moi-xay-rat-dep-thoang-mat-gan-nguyen-huu-tho-va-le-dai-hanh-da-nang.html',
#  'https://phongtro123.com/cho-thue-phong-tro-full-noi-that-tai-79-hoa-son-6-da-nang-pr707016.html']
